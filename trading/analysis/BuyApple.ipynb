# %%
# %matplotlib inline
import pandas as pd
import pyfolio as pf

# %%
perf = pd.read_pickle('test.pickle')
perf.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /home/nud3l/GitHub/pyfolio/pyfolio/lib/python3.4/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      51             with open(path, 'rb') as fh:
# ---> 52                 return pkl.load(fh)
#      53         except Exception:
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0x80 in position 1: ordinal not in range(128)
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# /home/nud3l/GitHub/pyfolio/pyfolio/lib/python3.4/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      56                 with open(path, 'rb') as fh:
# ---> 57                     return pc.load(fh, encoding=encoding, compat=False)
#      58
#
# /home/nud3l/GitHub/pyfolio/pyfolio/lib/python3.4/site-packages/pandas/compat/pickle_compat.py in load(fh, encoding, compat, is_verbose)
#     116
# --> 117         return up.load()
#     118     except:
#
# /usr/lib/python3.4/pickle.py in load(self)
#    1037                 assert isinstance(key, bytes_types)
# -> 1038                 dispatch[key[0]](self)
#    1039         except _Stop as stopinst:
#
# /usr/lib/python3.4/pickle.py in load_short_binstring(self)
#    1209         data = self.read(len)
# -> 1210         self.append(self._decode_string(data))
#    1211     dispatch[SHORT_BINSTRING[0]] = load_short_binstring
#
# /usr/lib/python3.4/pickle.py in _decode_string(self, value)
#    1157         else:
# -> 1158             return value.decode(self.encoding, self.errors)
#    1159
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0x80 in position 1: ordinal not in range(128)
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# /home/nud3l/GitHub/pyfolio/pyfolio/lib/python3.4/site-packages/pandas/io/pickle.py in read_pickle(path)
#      64     try:
# ---> 65         return try_read(path)
#      66     except:
#
# /home/nud3l/GitHub/pyfolio/pyfolio/lib/python3.4/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      61                 with open(path, 'rb') as fh:
# ---> 62                     return pc.load(fh, encoding=encoding, compat=True)
#      63
#
# /home/nud3l/GitHub/pyfolio/pyfolio/lib/python3.4/site-packages/pandas/compat/pickle_compat.py in load(fh, encoding, compat, is_verbose)
#     116
# --> 117         return up.load()
#     118     except:
#
# /usr/lib/python3.4/pickle.py in load(self)
#    1037                 assert isinstance(key, bytes_types)
# -> 1038                 dispatch[key[0]](self)
#    1039         except _Stop as stopinst:
#
# /usr/lib/python3.4/pickle.py in load_short_binstring(self)
#    1209         data = self.read(len)
# -> 1210         self.append(self._decode_string(data))
#    1211     dispatch[SHORT_BINSTRING[0]] = load_short_binstring
#
# /usr/lib/python3.4/pickle.py in _decode_string(self, value)
#    1157         else:
# -> 1158             return value.decode(self.encoding, self.errors)
#    1159
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0x80 in position 1: ordinal not in range(128)
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# /home/nud3l/GitHub/pyfolio/pyfolio/lib/python3.4/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      51             with open(path, 'rb') as fh:
# ---> 52                 return pkl.load(fh)
#      53         except Exception:
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0x80 in position 1: ordinal not in range(128)
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# /home/nud3l/GitHub/pyfolio/pyfolio/lib/python3.4/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      56                 with open(path, 'rb') as fh:
# ---> 57                     return pc.load(fh, encoding=encoding, compat=False)
#      58
#
# /home/nud3l/GitHub/pyfolio/pyfolio/lib/python3.4/site-packages/pandas/compat/pickle_compat.py in load(fh, encoding, compat, is_verbose)
#     116
# --> 117         return up.load()
#     118     except:
#
# /usr/lib/python3.4/pickle.py in load(self)
#    1037                 assert isinstance(key, bytes_types)
# -> 1038                 dispatch[key[0]](self)
#    1039         except _Stop as stopinst:
#
# /home/nud3l/GitHub/pyfolio/pyfolio/lib/python3.4/site-packages/pandas/compat/pickle_compat.py in load_reduce(self)
#      16
# ---> 17     if type(args[0]) is type:
#      18         n = args[0].__name__
#
# IndexError: tuple index out of range
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-024be558d38e> in <module>()
# ----> 1 perf = pd.read_pickle('test.pickle')
#       2 perf.head()
#
# /home/nud3l/GitHub/pyfolio/pyfolio/lib/python3.4/site-packages/pandas/io/pickle.py in read_pickle(path)
#      66     except:
#      67         if PY3:
# ---> 68             return try_read(path, encoding='latin1')
#      69         raise
#      70
#
# /home/nud3l/GitHub/pyfolio/pyfolio/lib/python3.4/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#      60             except:
#      61                 with open(path, 'rb') as fh:
# ---> 62                     return pc.load(fh, encoding=encoding, compat=True)
#      63
#      64     try:
#
# /home/nud3l/GitHub/pyfolio/pyfolio/lib/python3.4/site-packages/pandas/compat/pickle_compat.py in load(fh, encoding, compat, is_verbose)
#     115         up.is_verbose = is_verbose
#     116
# --> 117         return up.load()
#     118     except:
#     119         raise
#
# /usr/lib/python3.4/pickle.py in load(self)
#    1036                     raise EOFError
#    1037                 assert isinstance(key, bytes_types)
# -> 1038                 dispatch[key[0]](self)
#    1039         except _Stop as stopinst:
#    1040             return stopinst.value
#
# /home/nud3l/GitHub/pyfolio/pyfolio/lib/python3.4/site-packages/pandas/compat/pickle_compat.py in load_reduce(self)
#      15     func = stack[-1]
#      16
# ---> 17     if type(args[0]) is type:
#      18         n = args[0].__name__
#      19
#
# IndexError: tuple index out of range

# %%
returns, positions, transactions, gross_lev = pf.utils.extract_rets_pos_txn_from_zipline(perf)
